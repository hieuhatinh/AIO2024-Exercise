# %%
import torch
import torch.nn as nn
from torch.optim import SGD
from torchvision import transforms
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
batch_size = 512
num_epochs = 300
lr = 0.01

# %%
train_dataset = FashionMNIST(root='./data', train=True,
                             download=True, transform=transforms.ToTensor())
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
test_dataset = FashionMNIST(root='./data', train=False,
                            download=True, transform=transforms.ToTensor())
test_loader = DataLoader(test_dataset, batch_size)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 15.8MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 267kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 4.88MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 16.3MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.layer1(x)
        x = self.sigmoid(x)
        x = self.layer2(x)
        x = self.sigmoid(x)
        x = self.layer3(x)
        x = self.sigmoid(x)
        x = self.layer4(x)
        x = self.sigmoid(x)
        x = self.layer5(x)
        x = self.sigmoid(x)
        output = self.output(x)
        return output

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = MLP(input_dims=784,
            hidden_dims=128,
            output_dims=10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = SGD(model.parameters(), lr=lr)

# %%
train_losses = []
train_acc = []
val_losses = []
val_acc = []

for epoch in range(num_epochs):
    model.train()
    t_loss = 0
    t_acc = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        t_loss += loss.item()
        t_acc += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    t_loss /= len(train_loader)
    train_losses.append(t_loss)
    t_acc /= cnt
    train_acc.append(t_acc)

    model.eval()
    v_loss = 0
    v_acc = 0
    cnt = 0
    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            v_loss += loss.item()
            v_acc += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
        v_loss /= len(test_loader)
        val_losses.append(v_loss)
        v_acc /= cnt
        val_acc.append(v_acc)
    print(f'Epoch {epoch+1}\tTraining Loss: {t_loss:.3f}\tValidation Loss: {v_loss:.3f}')
# Out:
# Epoch 1	Training Loss: 2.308	Validation Loss: 2.303
# Epoch 2	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 3	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 4	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 5	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 6	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 7	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 8	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 9	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 10	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 11	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 12	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 13	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 14	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 15	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 16	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 17	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 18	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 19	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 20	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 21	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 22	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 23	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 24	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 25	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 26	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 27	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 28	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 29	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 30	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 31	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 32	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 33	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 34	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 35	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 36	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 37	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 38	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 39	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 40	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 41	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 42	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 43	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 44	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 45	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 46	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 47	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 48	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 49	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 50	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 51	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 52	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 53	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 54	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 55	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 56	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 57	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 58	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 59	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 60	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 61	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 62	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 63	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 64	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 65	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 66	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 67	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 68	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 69	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 70	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 71	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 72	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 73	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 74	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 75	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 76	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 77	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 78	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 79	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 80	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 81	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 82	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 83	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 84	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 85	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 86	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 87	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 88	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 89	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 90	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 91	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 92	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 93	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 94	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 95	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 96	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 97	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 98	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 99	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 100	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 101	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 102	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 103	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 104	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 105	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 106	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 107	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 108	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 109	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 110	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 111	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 112	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 113	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 114	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 115	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 116	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 117	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 118	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 119	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 120	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 121	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 122	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 123	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 124	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 125	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 126	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 127	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 128	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 129	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 130	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 131	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 132	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 133	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 134	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 135	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 136	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 137	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 138	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 139	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 140	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 141	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 142	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 143	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 144	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 145	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 146	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 147	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 148	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 149	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 150	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 151	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 152	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 153	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 154	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 155	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 156	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 157	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 158	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 159	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 160	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 161	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 162	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 163	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 164	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 165	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 166	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 167	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 168	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 169	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 170	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 171	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 172	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 173	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 174	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 175	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 176	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 177	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 178	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 179	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 180	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 181	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 182	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 183	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 184	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 185	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 186	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 187	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 188	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 189	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 190	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 191	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 192	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 193	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 194	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 195	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 196	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 197	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 198	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 199	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 200	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 201	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 202	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 203	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 204	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 205	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 206	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 207	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 208	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 209	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 210	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 211	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 212	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 213	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 214	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 215	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 216	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 217	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 218	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 219	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 220	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 221	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 222	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 223	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 224	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 225	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 226	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 227	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 228	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 229	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 230	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 231	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 232	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 233	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 234	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 235	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 236	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 237	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 238	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 239	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 240	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 241	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 242	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 243	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 244	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 245	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 246	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 247	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 248	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 249	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 250	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 251	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 252	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 253	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 254	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 255	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 256	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 257	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 258	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 259	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 260	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 261	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 262	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 263	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 264	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 265	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 266	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 267	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 268	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 269	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 270	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 271	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 272	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 273	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 274	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 275	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 276	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 277	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 278	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 279	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 280	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 281	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 282	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 283	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 284	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 285	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 286	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 287	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 288	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 289	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 290	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 291	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 292	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 293	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 294	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 295	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 296	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 297	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 298	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 299	Training Loss: 2.303	Validation Loss: 2.303
# Epoch 300	Training Loss: 2.303	Validation Loss: 2.303

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

ax[0, 0].plot(train_losses)
ax[0, 0].set_title('Train Loss')
ax[0, 0].set_xlabel('Epoch')
ax[0, 0].set_ylabel('Loss')

ax[0, 1].plot(val_losses)
ax[0, 1].set_title('Validation Loss')
ax[0, 1].set_xlabel('Epoch')
ax[0, 1].set_ylabel('Loss')

ax[1, 0].plot(train_acc, color='orange')
ax[1, 0].set_title('Train Accuracy')
ax[1, 0].set_xlabel('Epoch')
ax[1, 0].set_ylabel('Accuracy')

ax[1, 1].plot(val_acc, color='orange')
ax[1, 1].set_title('Validation Accuracy')
ax[1, 1].set_xlabel('Epoch')
ax[1, 1].set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
test_target = []
test_predict = []
with torch.no_grad():
    for X, y in test_loader:
        X, y = X.to(device), y.to(device)
        outputs = model(X)
        test_target.append(y.cpu())
        test_predict.append(outputs.cpu())

test_predict = torch.cat(test_predict)
test_target = torch.cat(test_target)
acc = (torch.argmax(test_predict, 1) == test_target).sum().item() / len(test_target)
acc
# Out:
# 0.1
