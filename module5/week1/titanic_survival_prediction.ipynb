# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
dataset_path = './data/titanic_modified_dataset.csv'
df = pd.read_csv(
    dataset_path,
    index_col='PassengerId'
)

# %%
df.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# PassengerId
# 1                 3    0  22.0      1      0   7.2500         0      0
# 2                 1    1  38.0      1      0  71.2833         1      1
# 3                 3    1  26.0      0      0   7.9250         0      2
# 4                 1    1  35.0      1      0  53.1000         0      1
# 5                 3    0  35.0      0      0   8.0500         0      0
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %%
# Chia X, y
dataset_arr = df.to_numpy().astype(np.float64)
X, y = dataset_arr[:, :-1], dataset_arr[:, -1]

# %%
# thêm bias vào X
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X),
                     axis=1)

# %%
X_b
# Out:
# array([[ 1.    ,  3.    ,  0.    , ...,  7.25  ,  0.    ,  0.    ],
#        [ 1.    ,  1.    ,  1.    , ..., 71.2833,  1.    ,  1.    ],
#        [ 1.    ,  3.    ,  1.    , ...,  7.925 ,  0.    ,  2.    ],
#        ...,
#        [ 1.    ,  3.    ,  1.    , ..., 23.45  ,  0.    ,  2.    ],
#        [ 1.    ,  1.    ,  0.    , ..., 30.    ,  1.    ,  0.    ],
#        [ 1.    ,  3.    ,  0.    , ...,  7.75  ,  2.    ,  0.    ]])

# %%
# Chia tập train, val, test
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X_b, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
# Chuẩn hóa dữ liệu
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
X_train
# Out:
# array([[ 1.        ,  0.8380325 , -0.73366996, ..., -0.34812766,
#          0.89679528, -0.55130115],
#        [ 1.        , -1.55141486, -0.73366996, ...,  1.76556546,
#         -0.60106922, -0.55130115],
#        [ 1.        ,  0.8380325 , -0.73366996, ..., -0.47988477,
#         -0.60106922, -0.55130115],
#        ...,
#        [ 1.        ,  0.8380325 , -0.73366996, ..., -0.48238806,
#          2.39465977, -0.55130115],
#        [ 1.        ,  0.8380325 , -0.73366996, ..., -0.22655193,
#         -0.60106922, -0.55130115],
#        [ 1.        ,  0.8380325 , -0.73366996, ..., -0.05432564,
#          2.39465977,  1.3289577 ]])

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# Hàm dự đoán
def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmoid(dot_product)
    return y_hat

# hàm tính loss
def compute_loss(y_hat, y):
    y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)
    return (-y*np.log(y_hat) - (1 - y)*np.log(1 - y_hat)).mean()

# Hàm tính gradient
def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

# Hàm cập nhật trọng số
def update_theta(theta, gradient, lr):
    return theta - lr*gradient

# Hàm tính độ chính xác
def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    return acc

# %%
lr = 0.01
epochs = 100
batch_size = 16

np.random.seed(random_state)
theta = np.random.uniform(size=X_train.shape[1])

# %%
# Huấn luyện mô hình
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)
        train_loss = compute_loss(y_hat, y_i)
        train_batch_losses.append(train_loss)

        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print(
        f'\nEPOCH {epoch + 1}: \t Training loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1: 	 Training loss: 0.670	Validation loss: 0.582
#
# EPOCH 2: 	 Training loss: 0.640	Validation loss: 0.567
#
# EPOCH 3: 	 Training loss: 0.614	Validation loss: 0.555
#
# EPOCH 4: 	 Training loss: 0.592	Validation loss: 0.544
#
# EPOCH 5: 	 Training loss: 0.572	Validation loss: 0.535
#
# EPOCH 6: 	 Training loss: 0.554	Validation loss: 0.528
#
# EPOCH 7: 	 Training loss: 0.539	Validation loss: 0.522
#
# EPOCH 8: 	 Training loss: 0.526	Validation loss: 0.517
#
# EPOCH 9: 	 Training loss: 0.514	Validation loss: 0.513
#
# EPOCH 10: 	 Training loss: 0.504	Validation loss: 0.509
#
# EPOCH 11: 	 Training loss: 0.495	Validation loss: 0.507
#
# EPOCH 12: 	 Training loss: 0.487	Validation loss: 0.505
#
# EPOCH 13: 	 Training loss: 0.480	Validation loss: 0.503
#
# EPOCH 14: 	 Training loss: 0.474	Validation loss: 0.502
#
# EPOCH 15: 	 Training loss: 0.468	Validation loss: 0.501
#
# EPOCH 16: 	 Training loss: 0.463	Validation loss: 0.500
#
# EPOCH 17: 	 Training loss: 0.459	Validation loss: 0.500
#
# EPOCH 18: 	 Training loss: 0.455	Validation loss: 0.500
#
# EPOCH 19: 	 Training loss: 0.452	Validation loss: 0.500
#
# EPOCH 20: 	 Training loss: 0.449	Validation loss: 0.499
#
# EPOCH 21: 	 Training loss: 0.446	Validation loss: 0.500
#
# EPOCH 22: 	 Training loss: 0.443	Validation loss: 0.500
#
# EPOCH 23: 	 Training loss: 0.441	Validation loss: 0.500
#
# EPOCH 24: 	 Training loss: 0.439	Validation loss: 0.500
#
# EPOCH 25: 	 Training loss: 0.437	Validation loss: 0.500
#
# EPOCH 26: 	 Training loss: 0.435	Validation loss: 0.501
#
# EPOCH 27: 	 Training loss: 0.434	Validation loss: 0.501
#
# EPOCH 28: 	 Training loss: 0.432	Validation loss: 0.502
#
# EPOCH 29: 	 Training loss: 0.431	Validation loss: 0.502
#
# EPOCH 30: 	 Training loss: 0.430	Validation loss: 0.502
#
# EPOCH 31: 	 Training loss: 0.429	Validation loss: 0.503
#
# EPOCH 32: 	 Training loss: 0.428	Validation loss: 0.503
#
# EPOCH 33: 	 Training loss: 0.427	Validation loss: 0.504
#
# EPOCH 34: 	 Training loss: 0.426	Validation loss: 0.504
#
# EPOCH 35: 	 Training loss: 0.425	Validation loss: 0.504
#
# EPOCH 36: 	 Training loss: 0.424	Validation loss: 0.505
#
# EPOCH 37: 	 Training loss: 0.424	Validation loss: 0.505
#
# EPOCH 38: 	 Training loss: 0.423	Validation loss: 0.506
#
# EPOCH 39: 	 Training loss: 0.422	Validation loss: 0.506
#
# EPOCH 40: 	 Training loss: 0.422	Validation loss: 0.506
#
# EPOCH 41: 	 Training loss: 0.421	Validation loss: 0.507
#
# EPOCH 42: 	 Training loss: 0.421	Validation loss: 0.507
#
# EPOCH 43: 	 Training loss: 0.420	Validation loss: 0.507
#
# EPOCH 44: 	 Training loss: 0.420	Validation loss: 0.508
#
# EPOCH 45: 	 Training loss: 0.420	Validation loss: 0.508
#
# EPOCH 46: 	 Training loss: 0.419	Validation loss: 0.509
#
# EPOCH 47: 	 Training loss: 0.419	Validation loss: 0.509
#
# EPOCH 48: 	 Training loss: 0.418	Validation loss: 0.509
#
# EPOCH 49: 	 Training loss: 0.418	Validation loss: 0.510
#
# EPOCH 50: 	 Training loss: 0.418	Validation loss: 0.510
#
# EPOCH 51: 	 Training loss: 0.417	Validation loss: 0.510
#
# EPOCH 52: 	 Training loss: 0.417	Validation loss: 0.510
#
# EPOCH 53: 	 Training loss: 0.417	Validation loss: 0.511
#
# EPOCH 54: 	 Training loss: 0.417	Validation loss: 0.511
#
# EPOCH 55: 	 Training loss: 0.416	Validation loss: 0.511
#
# EPOCH 56: 	 Training loss: 0.416	Validation loss: 0.512
#
# EPOCH 57: 	 Training loss: 0.416	Validation loss: 0.512
#
# EPOCH 58: 	 Training loss: 0.416	Validation loss: 0.512
#
# EPOCH 59: 	 Training loss: 0.416	Validation loss: 0.512
#
# EPOCH 60: 	 Training loss: 0.415	Validation loss: 0.513
#
# EPOCH 61: 	 Training loss: 0.415	Validation loss: 0.513
#
# EPOCH 62: 	 Training loss: 0.415	Validation loss: 0.513
#
# EPOCH 63: 	 Training loss: 0.415	Validation loss: 0.513
#
# EPOCH 64: 	 Training loss: 0.415	Validation loss: 0.514
#
# EPOCH 65: 	 Training loss: 0.415	Validation loss: 0.514
#
# EPOCH 66: 	 Training loss: 0.415	Validation loss: 0.514
#
# EPOCH 67: 	 Training loss: 0.414	Validation loss: 0.514
#
# EPOCH 68: 	 Training loss: 0.414	Validation loss: 0.514
#
# EPOCH 69: 	 Training loss: 0.414	Validation loss: 0.515
#
# EPOCH 70: 	 Training loss: 0.414	Validation loss: 0.515
#
# EPOCH 71: 	 Training loss: 0.414	Validation loss: 0.515
#
# EPOCH 72: 	 Training loss: 0.414	Validation loss: 0.515
#
# EPOCH 73: 	 Training loss: 0.414	Validation loss: 0.515
#
# EPOCH 74: 	 Training loss: 0.414	Validation loss: 0.516
#
# EPOCH 75: 	 Training loss: 0.414	Validation loss: 0.516
#
# EPOCH 76: 	 Training loss: 0.413	Validation loss: 0.516
#
# EPOCH 77: 	 Training loss: 0.413	Validation loss: 0.516
#
# EPOCH 78: 	 Training loss: 0.413	Validation loss: 0.516
#
# EPOCH 79: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 80: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 81: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 82: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 83: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 84: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 85: 	 Training loss: 0.413	Validation loss: 0.517
#
# EPOCH 86: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 87: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 88: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 89: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 90: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 91: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 92: 	 Training loss: 0.413	Validation loss: 0.518
#
# EPOCH 93: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 94: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 95: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 96: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 97: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 98: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 99: 	 Training loss: 0.412	Validation loss: 0.519
#
# EPOCH 100: 	 Training loss: 0.412	Validation loss: 0.519

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
# Đánh giá mô hình
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set:')
print(f'Accuracy: {val_set_acc}')
print(f'Accuracy: {test_set_acc}')
# Out:
# Evaluation on validation and test set:
# Accuracy: 0.770949720670391
# Accuracy: 0.7752808988764045
