# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from nltk.tokenize import TweetTokenizer
from collections import defaultdict

# %%
dataset_path = './data/sentiment_analysis.csv'
df = pd.read_csv(dataset_path, index_col='id')

# %%
df.head()
# Out:
#     label                                              tweet
# id
# 1       0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2       0  Finally a transparant silicon case ^^ Thanks t...
# 3       0  We love this! Would you go? #talk #makememorie...
# 4       0  I'm wired I know I'm George I was made that wa...
# 5       1  What amazing service! Apple won't even talk to...

# %% [markdown]
# #### Tiền xử lý dữ liệu

# %%
# Hàm chuẩn hóa văn bản
def text_normalize(text):
    # Retweet old acronym 'RT' removal
    text = re.sub(r'RT[\s]+', '', text)

    # Hyperlinks removal
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)

    # Hashtags removal
    text = re.sub(r'#', '', text)

    # Punctuation removal
    text = re.sub(r'[~\w\s]', '', text)

    # Tokenization
    tokenizer = TweetTokenizer(
        preserve_case=False, 
        strip_handles=True,
        reduce_len=True
    )
    text_tokens = tokenizer.tokenize(text)
    return text_tokens

# %%
# bộ lưu giữ tần suất xuất hiện của các từ
def get_freqs(df):
    freqs = defaultdict(lambda: 0)
    for idx, row in df.iterrows():
        tweet = row['tweet']
        label = row['label']

        tokens = text_normalize(tweet)
        for token in tokens:
            pair = (token, label)
            freqs[pair] += 1
    return freqs

# %%
# hàm tạo vector đặc trưng
def get_feature(text, freqs):
    tokens = text_normalize(text)
    X = np.zeros(3)
    X[0] = 1

    for token in tokens: 
        X[1] += freqs[(token, 0)]
        X[2] += freqs[(token, 1)]
    
    return X

# %%
# Trích xuất đặc trưng toàn bộ dữ liệu
X = []
y = []

freqs = get_freqs(df)
for idx, row in df.iterrows():
    tweet = row['tweet']
    label = row['label']

    X_i = get_feature(tweet, freqs)
    X.append(X_i)
    y.append(label)

X = np.array(X)
y = np.array(y)

# %% [markdown]
# #### Chia bộ train, val, test

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %% [markdown]
# #### Chuẩn hóa dữ liệu

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# Hàm dự đoán
def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmoid(dot_product)
    return y_hat

# hàm tính loss
def compute_loss(y_hat, y):
    y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)
    return (-y*np.log(y_hat) - (1 - y)*np.log(1 - y_hat)).mean()

# Hàm tính gradient
def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

# Hàm cập nhật trọng số
def update_theta(theta, gradient, lr):
    return theta - lr*gradient

# Hàm tính độ chính xác
def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    return acc

# %%
lr = 0.01
epochs = 100
batch_size = 16

np.random.seed(random_state)
theta = np.random.uniform(size=X_train.shape[1])

# %%
# Huấn luyện mô hình
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)
        train_loss = compute_loss(y_hat, y_i)
        train_batch_losses.append(train_loss)

        gradient = compute_gradient(X_i, y_i, y_hat)
        theta = update_theta(theta, gradient, lr)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_losses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print(
        f'\nEPOCH {epoch + 1}: \t Training loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1: 	 Training loss: 0.661	Validation loss: 0.657
#
# EPOCH 2: 	 Training loss: 0.553	Validation loss: 0.550
#
# EPOCH 3: 	 Training loss: 0.527	Validation loss: 0.524
#
# EPOCH 4: 	 Training loss: 0.518	Validation loss: 0.514
#
# EPOCH 5: 	 Training loss: 0.513	Validation loss: 0.509
#
# EPOCH 6: 	 Training loss: 0.509	Validation loss: 0.505
#
# EPOCH 7: 	 Training loss: 0.506	Validation loss: 0.502
#
# EPOCH 8: 	 Training loss: 0.504	Validation loss: 0.499
#
# EPOCH 9: 	 Training loss: 0.502	Validation loss: 0.497
#
# EPOCH 10: 	 Training loss: 0.500	Validation loss: 0.495
#
# EPOCH 11: 	 Training loss: 0.498	Validation loss: 0.493
#
# EPOCH 12: 	 Training loss: 0.497	Validation loss: 0.491
#
# EPOCH 13: 	 Training loss: 0.496	Validation loss: 0.490
#
# EPOCH 14: 	 Training loss: 0.495	Validation loss: 0.489
#
# EPOCH 15: 	 Training loss: 0.494	Validation loss: 0.488
#
# EPOCH 16: 	 Training loss: 0.493	Validation loss: 0.487
#
# EPOCH 17: 	 Training loss: 0.493	Validation loss: 0.486
#
# EPOCH 18: 	 Training loss: 0.492	Validation loss: 0.486
#
# EPOCH 19: 	 Training loss: 0.492	Validation loss: 0.485
#
# EPOCH 20: 	 Training loss: 0.491	Validation loss: 0.485
#
# EPOCH 21: 	 Training loss: 0.491	Validation loss: 0.484
#
# EPOCH 22: 	 Training loss: 0.490	Validation loss: 0.484
#
# EPOCH 23: 	 Training loss: 0.490	Validation loss: 0.483
#
# EPOCH 24: 	 Training loss: 0.490	Validation loss: 0.483
#
# EPOCH 25: 	 Training loss: 0.490	Validation loss: 0.483
#
# EPOCH 26: 	 Training loss: 0.489	Validation loss: 0.482
#
# EPOCH 27: 	 Training loss: 0.489	Validation loss: 0.482
#
# EPOCH 28: 	 Training loss: 0.489	Validation loss: 0.482
#
# EPOCH 29: 	 Training loss: 0.489	Validation loss: 0.482
#
# EPOCH 30: 	 Training loss: 0.489	Validation loss: 0.482
#
# EPOCH 31: 	 Training loss: 0.489	Validation loss: 0.482
#
# EPOCH 32: 	 Training loss: 0.489	Validation loss: 0.481
#
# EPOCH 33: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 34: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 35: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 36: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 37: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 38: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 39: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 40: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 41: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 42: 	 Training loss: 0.488	Validation loss: 0.481
#
# EPOCH 43: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 44: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 45: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 46: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 47: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 48: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 49: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 50: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 51: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 52: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 53: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 54: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 55: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 56: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 57: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 58: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 59: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 60: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 61: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 62: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 63: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 64: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 65: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 66: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 67: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 68: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 69: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 70: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 71: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 72: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 73: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 74: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 75: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 76: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 77: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 78: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 79: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 80: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 81: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 82: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 83: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 84: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 85: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 86: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 87: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 88: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 89: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 90: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 91: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 92: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 93: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 94: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 95: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 96: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 97: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 98: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 99: 	 Training loss: 0.488	Validation loss: 0.480
#
# EPOCH 100: 	 Training loss: 0.488	Validation loss: 0.480

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
# Đánh giá mô hình
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)
print('Evaluation on validation and test set:')
print(f'Accuracy: {val_set_acc}')
print(f'Accuracy: {test_set_acc}')
# Out:
# Evaluation on validation and test set:
# Accuracy: 0.7632575757575758
# Accuracy: 0.7727272727272727
